# %%
import gurobi as gb
import networkx as nx
import matplotlib.pyplot as plt
import random

from networkx import bipartite
from IPython.display import SVG

# %%
random.seed(9)

# %% [markdown]
# # Generating complete bipartite graph

# %%
candidate_location_nb = 5
demand_nb = 30

G = bipartite.random_graph(candidate_location_nb, demand_nb, 1)

# %%
# %matplotlib inline
pos = nx.spring_layout(G)
nx.draw(G,pos, node_color='#A0CBE2', width=1, node_size=1200, 
        with_labels=True, hold=None, font_size=8)

# %%
c_nodes, d_nodes = bipartite.sets(G)

# %% [markdown]
# # Setting the graph attributes for our problem

# %%
min_demand = 100
max_demand = 500
demand = {i: random.randint(min_demand, max_demand) for i in d_nodes}
nx.set_node_attributes(G, demand, name="demand")

min_fixed_charge = 1000
max_fixed_charge = 10000
fixed_charge = {i: random.randint(min_fixed_charge, max_fixed_charge) \
                for i in c_nodes}
nx.set_node_attributes(G, fixed_charge, name="fixed charge")

min_distance = 50
max_distance = 100
distance = {(i,j): random.randint(min_distance, max_distance) \
            for i, j in G.edges}
nx.set_edge_attributes(G, distance, name="distance")

min_D = 60
max_D = 80    
D = {i: random.randint(min_D, max_D) for i in d_nodes}
nx.set_node_attributes(G, D, name="D")

v = random.randint(10, 50)

# %%
def regenerate_node(G, node):
    for (i, j) in G.edges(node):
        distance[(i, j)] = random.randint(min_distance, max_distance)
        G[i][j]["distance"] = distance[(i, j)]
    D[node] = random.randint(min_D, max_D)
    G.nodes[node]["D"] = D[node]

# %%
G.nodes(data=True)
# Out:
# NodeDataView({0: {'bipartite': 0, 'fixed charge': 3169}, 1: {'bipartite': 0, 'fixed charge': 9294}, 2: {'bipartite': 0, 'fixed charge': 2037}, 3: {'bipartite': 0, 'fixed charge': 7285}, 4: {'bipartite': 0, 'fixed charge': 2665}, 5: {'bipartite': 1, 'demand': 337, 'D': 65}, 6: {'bipartite': 1, 'demand': 413, 'D': 68}, 7: {'bipartite': 1, 'demand': 291, 'D': 65}, 8: {'bipartite': 1, 'demand': 236, 'D': 63}, 9: {'bipartite': 1, 'demand': 170, 'D': 79}, 10: {'bipartite': 1, 'demand': 195, 'D': 64}, 11: {'bipartite': 1, 'demand': 446, 'D': 60}, 12: {'bipartite': 1, 'demand': 103, 'D': 61}, 13: {'bipartite': 1, 'demand': 273, 'D': 61}, 14: {'bipartite': 1, 'demand': 357, 'D': 74}, 15: {'bipartite': 1, 'demand': 337, 'D': 66}, 16: {'bipartite': 1, 'demand': 409, 'D': 72}, 17: {'bipartite': 1, 'demand': 141, 'D': 69}, 18: {'bipartite': 1, 'demand': 271, 'D': 79}, 19: {'bipartite': 1, 'demand': 383, 'D': 60}, 20: {'bipartite': 1, 'demand': 415, 'D': 71}, 21: {'bipartite': 1, 'demand': 458, 'D': 69}, 22: {'bipartite': 1, 'demand': 120, 'D': 64}, 23: {'bipartite': 1, 'demand': 472, 'D': 75}, 24: {'bipartite': 1, 'demand': 294, 'D': 77}, 25: {'bipartite': 1, 'demand': 186, 'D': 68}, 26: {'bipartite
}), (2, 27, {'distance': 93}), (2, 28, {'distance': 83}), (2, 29, {'distance': 87}), (2, 30, {'distance': 86}), (2, 31, {'distance': 99}), (2, 32, {'distance': 94}), (2, 33, {'distance': 55}), (2, 34, {'distance': 72}), (3, 5, {'distance': 57}), (3, 6, {'distance': 87}), (3, 7, {'distance': 73}), (3, 8, {'distance': 78}), (3, 9, {'distance': 63}), (3, 10, {'distance': 75}), (3, 11, {'distance': 62}), (3, 12, {'distance': 86}), (3, 13, {'distance': 97}), (3, 14, {'distance': 51}), (3, 15, {'distance': 74}), (3, 16, {'distance': 88}), (3, 17, {'distance': 71}), (3, 18, {'distance': 50}), (3, 19, {'distance': 77}), (3, 20, {'distance': 57}), (3, 21, {'distance': 63}), (3, 22, {'distance': 64}), (3, 23, {'distance': 78}), (3, 24, {'distance': 67}), (3, 25, {'distance': 70}), (3, 26, {'distance': 55}), (3, 27, {'distance': 69}), (3, 28, {'distance': 90}), (3, 29, {'distance': 68}), (3, 30, {'distance': 56}), (3, 31, {'distance': 83}), (3, 32, {'distance': 100}), (3, 33, {'distance': 53}), (3, 34, {'distance': 51}), (4, 5, {'distance': 74}), (4, 6, {'distance': 99}), (4, 7, {'distance': 85}), (4, 8, {'distance': 77}), (4, 9, {'distance': 81}), (4, 10, {'distance': 72}), (4, 11, {'distance': 95}), (4, 12, {'distance': 99}), (4, 13, {'distance': 65}), (4, 14, {'distance': 86}), (4, 15, {'distance': 97}), (4, 16, {'distance': 54}), (4, 17, {'distance': 77}), (4, 18, {'distance': 91}), (4, 19, {'distance': 64}), (4, 20, {'distance': 56}), (4, 21, {'distance': 98}), (4, 22, {'distance': 75}), (4, 23, {'distance': 82}), (4, 24, {'distance': 73}), (4, 25, {'distance': 85}), (4, 26, {'distance': 73}), (4, 27, {'distance': 58}), (4, 28, {'distance': 92}), (4, 29, {'distance': 68}), (4, 30, {'distance': 60}), (4, 31, {'distance': 94}), (4, 32, {'distance': 66}), (4, 33, {'dis ...

# %% [markdown]
# # Checking if the graph is correct
# Here we need to check if all demand nodes have at least one edge where the distance is less than the maximum distance.<br\>
# If a node does not correspond to this constraint, we regenerate all the random numbers concerning the distance for this node

# %%
for node in d_nodes:
    min_d = max_demand
    while min_d > G.nodes[node]["D"]:
        for (i, j) in G.edges(node):
            min_d = G[i][j]["distance"] if G[i][j]["distance"] < min_d else min_d
        
        print("Node", node, "min_d", min_d, "D", G.nodes[node]["D"])
        if min_d > G.nodes[node]["D"]:
            print("Regeneration of node",node)
            regenerate_node(G, node)
            min_d = max_demand
        print()
# Out:
# Node 5 min_d 52 D 65
#
# Node 6 min_d 53 D 68
#
# Node 7 min_d 67 D 65
# Regeneration of node 7
#
# Node 7 min_d 60 D 68
#
# Node 8 min_d 62 D 63
#
# Node 9 min_d 62 D 79
#
# Node 10 min_d 71 D 64
# Regeneration of node 10
#
# Node 10 min_d 72 D 63
# Regeneration of node 10
#
# Node 10 min_d 53 D 80
#
# Node 11 min_d 50 D 60
#
# Node 12 min_d 55 D 61
#
# Node 13 min_d 58 D 61
#
# Node 14 min_d 51 D 74
#
# Node 15 min_d 51 D 66
#
# Node 16 min_d 52 D 72
#
# Node 17 min_d 55 D 69
#
# Node 18 min_d 50 D 79
#
# Node 19 min_d 52 D 60
#
# Node 20 min_d 56 D 71
#
# Node 21 min_d 60 D 69
#
# Node 22 min_d 50 D 64
#
# Node 23 min_d 54 D 75
#
# Node 24 min_d 52 D 77
#
# Node 25 min_d 62 D 68
#
# Node 26 min_d 55 D 64
#
# Node 27 min_d 58 D 62
#
# Node 28 min_d 51 D 77
#
# Node 29 min_d 65 D 69
#
# Node 30 min_d 56 D 63
#
# Node 31 min_d 59 D 62
#
# Node 32 min_d 57 D 73
#
# Node 33 min_d 51 D 74
#
# Node 34 min_d 50 D 64

# %%
hcf = gb.Model()

# %%
# Variable definition
x = hcf.addVars(c_nodes, vtype=gb.GRB.BINARY, name="x")

# %%
# Objective function
hcf.setObjective(x.prod(fixed_charge), gb.GRB.MINIMIZE)

# %%
# Every demand node should be linked to an established facility
N = {i:[j for _, j in G.edges(i) if G[i][j]["distance"] < G.nodes[i]["D"]]\
      for i in d_nodes}

hcf.addConstrs((x.sum(N[i]) >= 1 for i in d_nodes), name="covering")
hcf.update()
hcf.write('hcf1.lp')

# %%
hcf.optimize()
# Out:
# Optimize a model with 30 rows, 5 columns and 65 nonzeros
# Variable types: 0 continuous, 5 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+03, 9e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 22413.000000
# Presolve removed 30 rows and 5 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 22413
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.241300000000e+04, best bound 2.241300000000e+04, gap 0.0000%

# %%
x
# Out:
# {0: <gurobi.Var x[0] (value 1.0)>,
#  1: <gurobi.Var x[1] (value 1.0)>,
#  2: <gurobi.Var x[2] (value 0.0)>,
#  3: <gurobi.Var x[3] (value 1.0)>,
#  4: <gurobi.Var x[4] (value 1.0)>}

# %% [markdown]
# # Solution Drawing

# %%
# %matplotlib inline
plt.figure(figsize=(demand_nb // 2, demand_nb // 2))

pos = nx.spring_layout(G)

activated_edge = [(i, j) for i in d_nodes for j in N[i] if x[j].x > 0]
not_activated_edge = [(i, j) for i in d_nodes for j in N[i] if x[j].x <= 0]

nx.draw_networkx_edges (G, pos, edgelist=activated_edge, edge_color='r', width = 1.2)
nx.draw_networkx_edges (G, pos, edgelist=not_activated_edge, edge_color='black', width=0.5, alpha = 0.5)

nodelab = {i:i for i in G.nodes()}

active_facility = [i for i in c_nodes if x[i].x > 0]
not_active_facility = [i for i in c_nodes if x[i].x <= 0]

nx.draw_networkx_nodes(G, pos, with_labels=True, node_size=1000, nodelist=active_facility, node_color ='r')
nx.draw_networkx_nodes(G, pos, with_labels=True, node_size=1000, nodelist=not_active_facility + list(d_nodes), node_color ='#A0CBE2')

nx.draw_networkx_labels(G, pos, labels=nodelab);
nx.draw(G, pos, with_labels=True,  alpha=0.0, node_color ='b', node_size=500, nodelabels=nodelab)
